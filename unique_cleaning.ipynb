# %%
import pandas as pd
import numpy as np

import requests
import os

from dotenv import load_dotenv

import concurrent.futures
import threading
import time

from ipynb.fs.defs.api_data_collection import get_api_data

# %%
#########################################
# STEP 4c: CHECK DATA ACCURACY          #
#########################################
df3 = pd.read_csv('BACKUP.csv')

disc = 0

for track in range(0, 2750):
    if df3.at[track, 'spotify track id'] == df3.at[track, 'api track id']:
        disc = 0
        continue
    else:
        disc = 1
        print(f"Disconnect Found on Row {track}!")
        break

if disc == 0:
    print("No disconnect. Data matches!")
# Out:
# No disconnect. Data matches!

# %%
#########################################
# STEP 5: FILL ROWS WITH API ERRORS     #
######################################### 

for i in range(1,df3.shape[0]):
    # check to see which rows of sheet do not include api data
    if df3.iloc[i,4] == None:
        # run api call again
        print(f"Retry: Row {i}")
        get_api_data(i)

d3
# Out:
#                           track title       track artist  \
# 0                    Tear in My Heart  Twenty One Pilots
# 1                 Fun (feat. Tove Lo)           Coldplay
# 2                    Someone Like You              Adele
# 3                           Immortals       Fall Out Boy
# 4     Scary Monsters and Nice Sprites           Skrillex
# ...                               ...                ...
# 2745                   Keep Her Close             ODESZA
# 2746           Memories That You Call             ODESZA
# 2747             My Friends Never Die             ODESZA
# 2748                            Light             ODESZA
# 2749                  If There's Time             ODESZA
#
#                          track spotify url        spotify track id  \
# 0     spotify:track:3bnVBN67NBEzedqQuWrpP4  3bnVBN67NBEzedqQuWrpP4
# 1     spotify:track:7fJFDK6XjYsXcMKNHESbot  7fJFDK6XjYsXcMKNHESbot
# 2     spotify:track:4kflIGfjdZJW4ot2ioixTB  4kflIGfjdZJW4ot2ioixTB
# 3     spotify:track:3Te8uLyit6X3ncNW8Fp3K2  3Te8uLyit6X3ncNW8Fp3K2
# 4     spotify:track:4rwpZEcnalkuhPyGkEdhu0  4rwpZEcnalkuhPyGkEdhu0
# ...                                    ...                     ...
# 2745  spotify:track:0XhFy7NAFb8b1grm26Xwh2  0XhFy7NAFb8b1grm26Xwh2
# 2746  spotify:track:2gpVdtEWFwUyl6uLLmvBzW  2gpVdtEWFwUyl6uLLmvBzW
# 2747  spotify:track:2eMh8ISgK9dylE51SJUixA  2eMh8ISgK9dylE51SJUixA
# 2748  spotify:track:6GAKSwEDt4y77MwPudwXkM  6GAKSwEDt4y77MwPudwXkM
# 2749  spotify:track:1a5Hi6hk75ftgzAVMkj5Lw  1a5Hi6hk75ftgzAVMkj5Lw
#
#                 api track id  \
# 0     3bnVBN67NBEzedqQuWrpP4
# 1     7fJFDK6XjYsXcMKNHESbot
# 2     4kflIGfjdZJW4ot2ioixTB
# 3     3Te8uLyit6X3ncNW8Fp3K2
# 4     4rwpZEcnalkuhPyGkEdhu0
# ...                      ...
# 2745  0XhFy7NAFb8b1grm26Xwh2
# 2746  2gpVdtEWFwUyl6uLLmvBzW
# 2747  2eMh8ISgK9dylE51SJUixA
# 2748  6GAKSwEDt4y77MwPudwXkM
# 2749  1a5Hi6hk75ftgzAVMkj5Lw
#
#                                                      id  key   mode camelot  \
# 0      dGVhci1pbi1teS1oZWFydC10d2VudHktb25lLXBpbG90cw==    D  major     10B
# 1                  ZnVuLWZlYXQtdG92ZS1sby1jb2xkcGxheQ==    C  major      8B
# 2                      c29tZW9uZS1saWtlLXlvdS1hZGVsZQ==    A  major     11B
# 3                      aW1tb3J0YWxzLWZhbGwtb3V0LWJveQ==    D  major     10B
# 4     c2NhcnktbW9uc3RlcnMtYW5kLW5pY2Utc3ByaXRlcy1za3...    G  minor      6A
# ...                                                 ...  ...    ...     ...
# 2745                       a2VlcC1oZXItY2xvc2Utb2Rlc3ph    A  minor      8A
# 2746  bWVtb3JpZXMtdGhhdC15b3UtY2FsbC1vZGVzemEtbW9uc2...   Bb  major      6B
# 2747               bXktZnJpZW5kcy1uZXZlci1kaWUtb2Rlc3ph    E  minor      9A
# 2748                                                NaN  NaN    NaN     NaN
# 2749                                                NaN  NaN    NaN     NaN
#
#       tempo duration  popularity  energy  danceability  happiness  \
# 0     120.0     3:08        78.0    63.0          66.0       45.0
# 1     134.0     4:28        58.0    74.0          49.0       22.0
# 2     135.0     4:45        80.0    32.0          56.0       29.0
# 3     108.0     3:09        79.0    87.0          62.0       48.0
# 4     140.0     4:03        65.0    94.0          52.0       32.0
# ...     ...      ...         ...     ...           ...        ...
# 2745  130.0     3:34        41.0    85.0          49.0       50.0
# 2746  120.0     3:40        51.0    58.0          64.0       19.0
# 2747  170.0     2:52        48.0    60.0          49.0       56.0
# 2748    NaN      NaN         NaN     NaN           NaN        NaN
# 2749    NaN      NaN         NaN     NaN           NaN        NaN
#
#       acousticness  instrumentalness  liveness  speechiness loudness
# 0              2.0               0.0       7.0          5.0    -5 dB
# 1             27.0               0.0       9.0          4.0    -5 dB
# 2             89.0               0.0      10.0          3.0    -8 dB
# 3              0.0               0.0      67.0          7.0    -4 dB
# 4              0.0              56.0      12.0          8.0    -4 dB
# ...            ...               ...       ...          ...      ...
# 2745           3.0               4.0      22.0          5.0    -6 dB
# 2746           1.0              84.0      12.0          3.0    -5 dB
# 2747           0.0              88.0       9.0          4.0    -8 dB
# 2748           NaN               NaN       NaN          NaN      NaN
# 2749           NaN               NaN       NaN          NaN      NaN
#
# [2750 rows x 20 columns]
